# %% [markdown]
# # Project 1

# %% [markdown]
# <strong> Team ID: 17 (Chiron) </strong>
#
# - Team members:
# 1.	Full name: Dinara Tursyn
# Student ID: 191107035
# 2.	Full name: Beibarys Rysbek
# Student ID: 201107030
# 3.	Full name: Mohamed Ibrahim
# Student ID: 201117001

# %%
# Import libraries
import requests
import re # regular expressions
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

# %%
# use beautiful soup and selenium
CHROME_DRIVER_PATH = r'D:/загрузки/chromedriver.exe'
driver = webdriver.Chrome(CHROME_DRIVER_PATH)

# %%
total = []

# %%
# set the necessary pages
# items on the front page has tags <div class="item ddl_product a-card"...</div>
# search dataset of mobile phones
# output the full list

# %%
pages = 50

for page in range(1,pages):
    url = "https://market.kz/elektronika/telefony/mobilnye-telefony/?page=" + str(page) + "/"
    driver.get(url)
    content = driver.page_source
    soup = BeautifulSoup(content)
    for block in soup.findAll('div', attrs={'class':'item ddl_product a-card'}): 
        name_text = block.find('a', attrs={'class': 'a-card__link'}).get_text(strip = True)
        price = block.find('div', attrs={'class':'a-card__price'}).text
        description = block.find('span', attrs={'class':'description-name'}).text
        phone_model = block.find('p', attrs={'class':'a-card__breadcrumbs'}).text
        city = block.find('div', attrs={'class':'card-stats__item'}).get_text(strip = True)
        date = block.find('span', attrs={'class':'add-date'}).text
        view = block.find('span', attrs={'class':'card-stats__views views'}).text
        new = ((name_text, price, description, phone_model, city, date, view))
        total.append(new)

# %%
len(total)
# Out:
# 1020

# %%
total
# Out:
# [('Телефон',
#   'Договорная цена',
#   'Память 32гб \nСостояние среднее \nОтпечаток работает \nЗарядка есть',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  15 '),
#  ('Продам iPhone 11 Pro Max 64 gb',
#   '365 000 ₸',
#   'Продам IPhone 11 Pro Max 64 gb \n\nТелефон в идеальном состоянии, на экране плёнка с момента покупки \n\nПокупался в... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  89 '),
#  ('IPhone 24Kt Gold Kazakhstan',
#   '180 000 ₸',
#   'Продам эксклюзивный iPhone 7/128GB.\nСостояние отличное, без сколов. Герб Казахстана выполнен из золота 24 карата.... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  817 '),
#  ('iPhone 6 32 GB',
#   '35 000 ₸',
#   'Все в хорошем состоянии все работает с коробкой\nСостояние батареи 85%\nОтпечатка работает \nВсе есть коробка зарядка с... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  140 '),
#  ('Samsung J2',
#   '35 000 ₸',
#   'Срочно продам смартфон J2 в идеальном состоянии, все работает интернет 4G, вай фай, ютуб, , и. Т. Д. Редко... ',
#   'Мобильные телефоны » Samsung',
#   'Павлодар',
#   '28 ноября 2020 г.',
#   '  124 '),
#  ('Продам Huawei pSmart 2018',
#   '20 000 ₸',
#   'Задняя камера не работает. Немного отходит дисплей. Память 32 Гб. Цвет: черный. Документы есть.',
#   'Мобильные телефоны » Huawei',
#   'Актобе',
#   '29 ноября 2020 г.',
#   '  221 '),
#  ('Продам самсунг а30 3/32',
#   '35 000 ₸',
#   'В хорошем состоянии не тупит доки есть минус на фото',
#   'Мобильные телефоны » Samsung',
#   'Павлодар',
#   '29 ноября 2020 г.',
#   '  0 '),
#  ('телефон',
#   '4 000 ₸',
#   'белый самсунг отлично состояние остальные телефон не работает',
#   'Мобильные телефоны » Samsung',
#   'Атырау',
#   '29 ноября 2020 г.',
#   '  0 '),
#  ('Redmi note 8 pro 6/128GB',
#   '93 000 ₸',
#   'Redmi note 8 pro 6/128Gb белый цвет сатылад жаксы жасап тур каропкасы бар, зарятчик, радной чехолбар. ОБМЕН ЖОК... ',
#   'Мобильные телефоны » Xiaomi',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  417 '),
#  ('Смартфон Samsung Galaxy S20+ plus 128GB',
#   '210 000 ₸',
#   '-Тип матрицы Dynamic AMOLED\n-Процессор Exynos 990\n-Объем оперативной памяти 8GB\n-Основная камера 64 Мп + 12 Мп + 12 Мп... ',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  29 '),
#  ('Айфон 5s в отличном состоянии',
#   '25 000 ₸',
#   'Одна хозяйка, в хорошем состоянии, не роняла, продаю в связи с тем что подарили другой,без зарядки',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  964 '),
#  ('HUAWEI pi40lait',
#   'Договорная цена',
#   'Новый Скину скока попросите🙂',
#   'Мобильные телефоны » Huawei',
#   'Павлодар',
#   '29 ноября 2020 г.',
#   '  32 '),
#  ('IPhone 7',
#   '85 000 ₸',
#   'IPhone 7 silver в хорошем состоянии. Без проблем выйду айклауд.',
#   'Мобильные телефоны » Apple',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  35 '),
#  ('Ceramik white 1 TB',
#   '270 000 ₸',
#   'Доброго времени суток. Продам или обменяю телефон самсунг S10 plus. В хорошем состояний. Работает четко и плавно. Озу... ',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  32 '),
#  ('Телефоны',
#   '12 000 ₸',
#   'Samsung Duos работает в идеальном состоянии, царапин экрана нет. Звук мощный. Простой Самсунг тоже работает без... ',
#   'Мобильные телефоны » Samsung',
#   'Уральск',
#   '29 ноября 2020 г.',
#   '  37 '),
#  ('продам iPhone 5s',
#   '15 000 ₸',
#   'Айфон 5s сатамын',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  17 '),
#  ('Vivo Y93 lite',
#   'Договорная цена',
#   'Продаю Vivo Y93 lite в отличном состоянии! Покупал 1. 5 месяца назад с нуля!',
#   'Мобильные телефоны » Vivo',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  26 '),
#  ('Продам самсунг',
#   '13 000 ₸',
#   'В хорошем состояние все работает, двух сим картная.',
#   'Мобильные телефоны » Samsung',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  30 '),
#  ('Продам телефон самсунг А 01core',
#   '40 000 ₸',
#   'Продам телефон за 40000.телефон новый этого года.пользуюсь 2 недели.еще 1 год гарантии.стоит бронь стекло,в... ',
#   'Мобильные телефоны » Samsung',
#   'Мамлютка',
#   '29 ноября 2020 г.',
#   '  3 '),
#  ('Продам Samsung J2',
#   '17 000 ₸',
#   'Продам Samsung J2\nВ идеальном состоянии, состояние нового телефона.\nДокументы, коробка, зарядка в комплекте.',
#   'Мобильные телефоны » Samsung',
#   'Павлодар',
#   '29 ноября 2020 г.',
#   '  84 '),
#  ('Телефон',
#   'Договорная цена',
#   'Новый, зарядкасы , корабы бар.',
#   'Мобильные телефоны » Другой',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  62 '),
#  ('Продам телефон',
#   '30 000 ₸',
#   'Продам телефон хорошем состоянии Samsung J5',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  127 '),
#  ('Продам сотовый телефон',
#   '30 000 ₸',
#   'Цвет золотистый, двухсимчитый',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  111 '),
#  ('Продам б/у телефон в отличном состоянии',
#   '37 000 ₸',
#   'В отличном состоянии Айфон 6',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  60 '),
#  ('iphone 11 обмен или продам телефон',
#   '245 000 ₸',
#   'В отличном состоянии полный комплект покупал в марте этого года \nНикаких царапин и ремонта',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  1 '),
#  ('Продам срочно айфон 7+, еще и Air pods',
#   '115 000 ₸',
#   'Продам Айфон 7+ на 32гб, с чехлом и защитным стеклом, + есть коробка ещё и в подарок айр подс (фейк), возможен обмен... ',
#   'Мобильные телефоны » Apple',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  84 '),
#  ('Vertu signature s design',
#   '75 000 ₸',
#   'Телефон Vertu Signature S Design — будоражит сознание при его появлении, ты думаешь о власти, которую он даёт. В нем... ',
#   'Мобильные телефоны » Vertu',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  8829 '),
#  ('Oppo a5s синего цвета',
#   '42 000 ₸',
#   'Oppo a5s Пользовались меньше годаПользовалась девушка*Полный комплектОбмен не интересуетКоробка доки все есть Цена... ',
#   'Мобильные телефоны » OPPO',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  0 '),
#  ('Обмен на nokia 6700',
#   'Договорная цена',
#   'Телефон в хорошем состоянии\n2 симка \nКамера есть\nОбмен на nokia 6700',
#   'Мобильные телефоны » Acer',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  13823 '),
#  ('ZTE патворд',
#   'Договорная цена',
#   'ZTE патворд с номером\nПродам или обмен на блок сигарет LD extra',
#   'Мобильные телефоны » ZTE',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  6844 '),
#  ('4 телефона продам',
#   'Договорная цена',
#   '1. Кара самсунго батарейка ауыстыру керек, 1500тнг\n2. Патворд iстид 1500тнг\n3. Nokia с фонариком 2000тнг\n4. Jinga... ',
#   'Мобильные телефоны » Nokia',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  13033 '),
#  ('Оригинал телефон 2симка',
#   '5 000 ₸',
#   'Jinga оригинал телефон 2 симка\nФлэшка вставляется\nКамера мп3 \nТелефон и зарядка\nПродам 5000 или обмен на нокия 6700, 515',
#   'Мобильные телефоны » Acer',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  16016 '),
#  ('А5 2016',
#   'Договорная цена',
#   'Samsung A5 2016 состояние новый\nМамашка устаган\nСульпактан 148мынга алгам\nДокумент бари бар\nСрочно продам',
#   'Мобильные телефоны » Samsung',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  10470 '),
#  ('J5 prime 2017 обмен на А3 17',
#   'Договорная цена',
#   'Samsung J5 prime в хорошем состоянии, 2017год. Вложении не требует, отпечатка работает. Минус жок. Обмен на А3 2017',
#   'Мобильные телефоны » Samsung',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  5786 '),
#  ('Nokia простой',
#   '2 000 ₸',
#   'Nokia с фонариком, чисто для связи пойдет, задней крышки нет это не проблема',
#   'Мобильные телефоны » Nokia',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  18218 '),
#  ('iphone SE 2020 64 gb',
#   '220 000 ₸',
#   'СОСТ 10/10\nдокумент есть\nзаряд наушник радной\nёмкость 100%',
#   'Мобильные телефоны » Apple',
#   'Актобе',
#   '29 ноября 2020 г.',
#   '  23 '),
#  ('IPhone 7 black 32gb.все работает,доки есть',
#   '55 000 ₸',
#   '',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  45 '),
#  ('Айфон 6 32',
#   '40 000 ₸',
#   'Продам Айфон 6 32 Гб с коробкой наушниками чехлом',
#   'Мобильные телефоны » Apple',
#   'Усть-Каменогорск',
#   '29 ноября 2020 г.',
#   '  47 '),
#  ('Samsung A10',
#   '40 000 ₸',
#   'Samsung A10 в новом состоянии. Куплен пару месяцев назад для учёбы. Полный комплект. Без минусов. Тянет любые игры на... ',
#   'Мобильные телефоны » Samsung',
#   'Тараз',
#   '29 ноября 2020 г.',
#   '  63 '),
#  ('Продам или обмен телефон',
#   '18 000 ₸',
#   'Продам нокию люмию 1020 в хорошем состоянии. Камера 41 мп. Играет громко. Доки и коробка есть. Или обменяю на самсунг... ',
#   'Мобильные телефоны » Nokia',
#   'Караганда',
#   '29 ноября 2020 г.',
#   '  255 '),
#  ('Продам                                    Телефон',
#   '105 000 ₸',
#   'Телефон в отличном состочний, есть торк. Без царапин доки зарятки все есть. 2 чехла в подарок.',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  36 '),
#  ('Продам телефон Samsung A6+',
#   'Договорная цена',
#   'Срочно продам телефон есть торг',
#   'Мобильные телефоны » Samsung',
#   'Альмерек',
#   '29 ноября 2020 г.',
#   '  37 '),
#  ('Oppo a5s красного цвета',
#   '42 000 ₸',
#   'Oppo a5s \nНовый \nПользовалась девушка\nТянет все игры \nНе лагает не зависает\nНа экране стекло \nВ комплекте коробка... ',
#   'Мобильные телефоны » OPPO',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  0 '),
#  ('Обменяю телефон',
#   'Договорная цена',
#   'Обменяю хонор 7а, пользовался месяц, 16 гб оперативка, целый, в ремонте не был, с коробкой и документами и зарядным,... ',
#   'Мобильные телефоны » Другой',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  19 '),
#  ('Продам Huawei p smart2019',
#   '55 000 ₸',
#   'Продам абсолютно новый телефон по цене договоримся',
#   'Мобильные телефоны » Huawei',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  25 '),
#  ('продам телефон',
#   '5 000 ₸',
#   '2простой телефон каждый 2000 самсунг 5000 позвоните 87751679382',
#   'Мобильные телефоны » Samsung',
#   'Атырау',
#   '29 ноября 2020 г.',
#   '  6 '),
#  ('IPhone 7+ в хорошем состоянии',
#   '110 000 ₸',
#   '',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  21 '),
#  ('Продаю Айфон 6',
#   '40 000 ₸',
#   'Продам айфон 6 64 гб минусов нет отпечатка все работает 40000 норм клиенту скидка есть',
#   'Мобильные телефоны » Другой',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  149 '),
#  ('Продам LG G4',
#   '10 000 ₸',
#   'Минус то что не работает камера. А так норм телефон',
#   'Мобильные телефоны » LG',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  30 '),
#  ('Продаю айфон 6 китайский память 128 гигов',
#   '25 000 ₸',
#   'Китайский память128 айклауд снят документы зарядка наушники оригинал',
#   'Мобильные телефоны » Apple',
#   'Караганда',
#   '29 ноября 2020 г.',
#   '  13 '),
#  ('продам телефон Samsung A51',
#   '85 000 ₸',
#   'Продам телефон Samsung A 51, полная комплектация, состояние нового, на гарантии. Причина продажи приобретение другого... ',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  50 '),
#  ('Айфон 11 про',
#   '400 000 ₸',
#   '64 гига в отличном состоянии не одной царапины',
#   'Мобильные телефоны » Apple',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  45 '),
#  ('Huawei p smart',
#   '40 000 ₸',
#   '',
#   'Мобильные телефоны » Huawei',
#   'Каскелен',
#   '29 ноября 2020 г.',
#   '  7 '),
#  ('IPhone 7 | 32GB | Black',
#   '105 000 ₸',
#   'В комплекте Коробка(imei проверите на месте)\nПроводные наушники Earpods (ориг)\nАдаптер зарядки(ориг)\nПровод lightning... ',
#   'Мобильные телефоны » Apple',
#   'Актобе',
#   '29 ноября 2020 г.',
#   '  26 '),
#  ('Huawei p smart',
#   '40 000 ₸',
#   '',
#   'Мобильные телефоны » Huawei',
#   'Каскелен',
#   '29 ноября 2020 г.',
#   '  7 '),
#  ('IPhone 7 | 32GB | Black',
#   '105 000 ₸',
#   'В комплекте Коробка(imei проверите на месте)\nПроводные наушники Earpods (ориг)\nАдаптер зарядки(ориг)\nПровод lightning... ',
#   'Мобильные телефоны » Apple',
#   'Актобе',
#   '29 ноября 2020 г.',
#   '  26 '),
#  ('Продам HUAWEI Y5',
#   '25 000 ₸',
#   'Телефон📱HUAWEI Y5\nТелефону 2 месяца, документы ,выписки ,чек, все есть, телефон в гарантии в центре "Мечта" \nМинусов... ',
#   'Мобильные телефоны » Huawei',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  38 '),
#  ('IPhone XR',
#   '165 000 ₸',
#   'Продам телефон в отличном состоянии, документы все в порядке, имеется гарантия! Срочно!!!!',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  7 '),
#  ('Apple Iphone 7 32 GB (розовое золото)',
#   '80 000 ₸',
#   'Диагональ 4.7, разрешение 1334*750(пикс),  встроенная память 32 GB , ,фотокамера 12 Мп ,Частота процессора  2340 МГЦ,... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  119 '),
#  ('Смартфон Xiaomi Redmi Note 8 Pro 6/64Gb Forest Green',
#   '75 000 ₸',
#   'Смартфон Xiaomi Redmi Note 8 Pro 6/64Gb Forest Green\n-Процессор MediaTek Helio G90T\n-Объем оперативной памяти... ',
#   'Мобильные телефоны » Xiaomi',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  23 '),
#  ('Смартфон Samsung Galaxy S4, 16GB, Black (GT-I9500)',
#   '30 000 ₸',
#   'Смартфон Samsung Galaxy S4, 16GB, Black (GT-I9500) \n-Тип матрицы цветной AMOLED\n-RAM 2GB\n-Основная камера 13... ',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  27 '),
#  ('Iphone 7+ plus 32gb',
#   '88 000 ₸',
#   'Продам iPhone 7 plus 32 gb без минусов работает всё корпус 8/10 в комплекте только сам телефон и чехол торг... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  92 '),
#  ('Смартфон',
#   '25 000 ₸',
#   'В отличном состоянии с документами',
#   'Мобильные телефоны » Huawei',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  16 '),
#  ('Телефон',
#   '45 000 ₸',
#   'Самсунг А7 2016. В хорошем состоянии.',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  40 '),
#  ('Продам телефон Oppo a3s',
#   '35 000 ₸',
#   'Телефон в хорошом состояние в комплекте три чехла и зарядка ничего не менял всё родное цвет тёмно фиолетовый\nПо другим... ',
#   'Мобильные телефоны » OPPO',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  29 '),
#  ('Продам Samsung a51',
#   'Договорная цена',
#   'Новый Samsung a51, 64gb \nСерый цвет',
#   'Мобильные телефоны » Samsung',
#   'Павлодар',
#   '29 ноября 2020 г.',
#   '  25 '),
#  ('Samsung galaxy j5  (2016)',
#   '5 000 ₸',
#   'На запчасти цена договорная',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  118 '),
#  ('Samsung A8 2018',
#   '55 000 ₸',
#   'Samsung A8 2018\nПолный комплект без наушников\nКоробка доки есть\nБез царапин,без трещин, на экране стекло\nПользовались... ',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  1 '),
#  ('Продам Айфон 6',
#   '40 000 ₸',
#   'Продам айфон 6, бу. Работает отлично! Есть на одном месте царапина, из за чего уценённый. \nВ комплекте: телефон,... ',
#   'Мобильные телефоны » Apple',
#   'Семей',
#   '29 ноября 2020 г.',
#   '  160 '),
#  ('Xiaomi redmi note 8t на 32gb и наушники jbl',
#   '50 000 ₸',
#   'Продаю телефон в идеальном состоянии , с коробкой, чехлом(купленным отдельно) и быстрой(заводской) зарядкой все в... ',
#   'Мобильные телефоны » Xiaomi',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  36 '),
#  ('Продам iPhon 11 64Gb black eSIM',
#   '260 000 ₸',
#   'Продам iPhone 11/64Gb black в идеальном состочние полный комплект коробка документы гарантия чехол на экране стекло... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  283 '),
#  ('Самсунг дж7 2016 год4 дж',
#   'Договорная цена',
#   'Самсунг дж7 2016 год 4дж память 16гиг минус нет батарея харашо держит заряд есть чехол и зарядка идеальное состояние... ',
#   'Мобильные телефоны » Samsung',
#   'Актобе',
#   '29 ноября 2020 г.',
#   '  1719 '),
#  ('Смартфон Xiaomi Redmi Note 8 64Gb Neptune Blue',
#   '65 000 ₸',
#   'Смартфон Xiaomi Redmi Note 8 4/64Gb Neptune Blue\n-RAM 4GB\n-Основная камера 48 Мп + 8 Мп + 2 Мп+ 2 Мп\n-Фронтальная... ',
#   'Мобильные телефоны » Xiaomi',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  23 '),
#  ('Samsung Galaxy J7 neo',
#   '25 000 ₸',
#   'Продаю свой смартфон Samsung Galaxy J7 neo. Состояние хорошее. Есть незаметная трещина внизу экрана. Звоните, пишите!',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  362 '),
#  ('Продам смартфон lg x4',
#   '40 000 ₸',
#   'Новый смартфон 32 GB , цвет темно синий',
#   'Мобильные телефоны » LG',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  63 '),
#  ('Продам телефон',
#   '75 000 ₸',
#   'Телефон в супер идеальном состоянии, без единой царапины, ни разу не падал, на экране стоит стекло, корпус всё время в... ',
#   'Мобильные телефоны » OPPO',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  1046 '),
#  ('Телефоны сотовые',
#   '5 000 ₸',
#   'Телефоны:\n"Nikia " - 2100 цена 5000тг,\n"Cамсунг" - цена 6500тг\nОба с зарядными устройствами, в рабочем состоянии.\n"... ',
#   'Мобильные телефоны » Nokia',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  22 '),
#  ('Продам сотовые телефоны',
#   '7 500 ₸',
#   'Продам Nokia asha 308 original,имеется коробка и документы в отличном состоянии.цена 7500. Samsung GT 1081... ',
#   'Мобильные телефоны » Nokia',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  31 '),
#  ('Айфон 6 32гб',
#   '25 000 ₸',
#   'Айфон 6сатам 25ке берп жиберем минусти айтам',
#   'Мобильные телефоны » Apple',
#   'Атырау',
#   '29 ноября 2020 г.',
#   '  0 '),
#  ('iPhone 11 Pro Max',
#   '370 000 ₸',
#   'Продам IPhone в отличном состоянии, без сколов и царапин. Версия на 2 физические сим-Карты. Пользовались аккуратно.... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  2 '),
#  ('Нокия 1681, простушка',
#   '4 500 ₸',
#   'Продаю оптом и в розницу разные типы кнопочных телефонов.\nОтправка по всему миру!\nДоставка по Алмате от 500 тг.\nДля... ',
#   'Мобильные телефоны » Nokia',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  32 '),
#  ('Продам                                    телефон',
#   '14 000 ₸',
#   'Продам телефон в рабочем состоянии, только сломано стекло',
#   'Мобильные телефоны » Huawei',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  34 '),
#  ('IPhone 6S',
#   '55 555 ₸',
#   'IPhone шестой S есть вариант обмен на другой телефон в комплекте есть зарядник документы коробок куплен году назад... ',
#   'Мобильные телефоны » Apple',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  24 '),
#  ('Samsung Galaxy А70. A8+ Replica КОПИЯ смартфон',
#   '33 000 ₸',
#   'Южнокорейские 100% Копии Replica\nSamsung Galaxy А70. A8+\nПроцессор МТК 6592\n8ми ядер\n\nЕсть Доставка по Казахстану',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  18745 '),
#  ('Айфон ХР сатылады срочно',
#   '160 000 ₸',
#   'Айфон ХР сатылады срочно 160 мын барлык заты бар',
#   'Мобильные телефоны » Apple',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  32 '),
#  ('Продам телефон Huawei P Smart 2019 3/32 GB',
#   '65 000 ₸',
#   'Пользвался телефоном месяц, в коробке есть гарантия от технодома и все что было при покупке, вместе с телефоном отдам... ',
#   'Мобильные телефоны » Huawei',
#   'Рудный',
#   '29 ноября 2020 г.',
#   '  1 '),
#  ('Самсунг А3 2017 жылгы 32 гб',
#   'Договорная цена',
#   'Кыз бала устаган тап таза царапин сынык жок кумайд нормально жасайд 4 ж устайд защитный бар сол сызылган экран тап... ',
#   'Телефоны, гаджеты » Мобильные телефоны',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  37 '),
#  ('Huawei p30 128gb',
#   '70 000 ₸',
#   'Ассалаумағалайкум.\nПродам телефон huawei p30 lite без минусов идеальное состояние, не зависает не тормозит,коробка... ',
#   'Мобильные телефоны » Huawei',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  43 '),
#  ('Samsung Galaxy j6',
#   '24 000 ₸',
#   '',
#   'Мобильные телефоны » Samsung',
#   'Кентау',
#   '29 ноября 2020 г.',
#   '  43 '),
#  ('Продам Galaxy mini в среднем состояний',
#   '5 000 ₸',
#   'Продаю т. К. Не нужный воляется',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  48 '),
#  ('Продам Samsung Galaxy Grand Prime',
#   '20 000 ₸',
#   'Состояние отличное , зарядку держит хорошо , коробка есть единственное нет комплектной зарядки.',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  73 '),
#  ('Nokia 105 с двумя симками',
#   '4 000 ₸',
#   'Пишите в или в ЛС, не звоните!\n\nЦена окончательная, торга и доставки нет.\n\nТелефон для звонков, две симкарты, чисто... ',
#   'Мобильные телефоны » Nokia',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  56 '),
#  ('Fly TS113 с тремя симкартами',
#   '5 000 ₸',
#   'Цена окончательная, торга и доставки нет.\n\nТелефон с тремя симкартами, коробки и зарядки в комплекте НЕТ.\n\nГОтов к... ',
#   'Мобильные телефоны » Fly',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  23 '),
#  ('SAMSUNG GT-E2252 с двумя симками',
#   '3 500 ₸',
#   'Цена окончательная, торга и доставки нет.\n\nДвухсимочный телефон для звонков. \nВ рабочем состоянии, коробки и зарядки в... ',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  44 '),
#  ('Nokia 105',
#   '4 000 ₸',
#   'Цена окончательная, торга и доставки нет.\n\nТелефон для звонков, две симкарты, полностью рабочий. \n\nЦена окончательная.',
#   'Мобильные телефоны » Nokia',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  56 '),
#  ('Samsung Galaxy s20 Ultra 5G',
#   '250 000 ₸',
#   'Телефон в идеальном техническом состояний!\n100Х ZOOM\n128GB \n100% оригинал\nMade in Vietnam\nОдин хозяин\nПокупали в... ',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  85 '),
#  ('Телефон',
#   'Договорная цена',
#   'Новый, корапка бар зарядкасы\n Бар.',
#   'Мобильные телефоны » Другой',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  42 '),
#  ('Телефон bluboo S8',
#   '15 000 ₸',
#   'Продам телефон, КИТАЙ Bluboo s8, аналог Самсунг s8. В рабочем состоянии, 32 гб. Все отлично работает, единственное... ',
#   'Мобильные телефоны » Другой',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  1280 '),
#  ('Samsung Note 10Plus',
#   '350 000 ₸',
#   'Продаётся Самсунг Ноут 10 плюс 📱\n🔵Цвет- Aura Blue\n⚫️Память-256гб\n▪️Коробка с полным комплектом имеется \n▫️В подарок... ',
#   'Мобильные телефоны » Samsung',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  110 '),
#  ('Xiaomi Redmi Note 8 Pro/6-128GB',
#   '85 000 ₸',
#   'Продам Xiaomi Redmi Note 8 Pro/6-128GB. Mineral Grey (Серый). \nБез единой царапины и без повреждений.\nБыл в... ',
#   'Мобильные телефоны » Xiaomi',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  23 '),
#  ('Huawei P20 pink',
#   '150 000 ₸',
#   '',
#   'Мобильные телефоны » Huawei',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  0 '),
#  ('Продаю срочно айфон про макс 11.',
#   '230 000 ₸',
#   'Продаю срочно хорошом состояния айфон про макс 11pro срочно мне нужен деньги вон очень хороший не сломани работает всё... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  146 '),
#  ('Срочно продам телефон',
#   '10 000 ₸',
#   'Сломан экран, во всем остальном вполне рабочий. Пишите звоните замена экрана стоит 8500. Новый стоит от 55К. Имеется... ',
#   'Мобильные телефоны » Lenovo',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  9 '),
#  ('Продам телефон самсунг А51 полный комплект',
#   '100 000 ₸',
#   'Состояние идеальное почти новый год гарантия полный комплект плюс чехол книжка память 128гб.',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  56 '),
#  ('Продаю айфон 11 black 128-',
#   '295 000 ₸',
#   'Новая!',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  35 '),
#  ('Oppo A5s',
#   '30 000 ₸',
#   'Телефон в хорошем состоянии',
#   'Мобильные телефоны » OPPO',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  0 '),
#  ('Продам запечатанный Iphone 12 Pro Max 128gb',
#   '620 000 ₸',
#   'Срочно продам новый запечатанный Iphone 12 Pro Max 128gb синий 620000 тенге срочно, в связи с тем что нужны деньги',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  4 '),
#  ('IPhone 6 satylady',
#   '45 000 ₸',
#   'Aifon 6 satylady 32 gb',
#   'Мобильные телефоны » Apple',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  78 '),
#  ('Подам телефон',
#   'Договорная цена',
#   'Подам телефон и Huawei Y5 2019 купил 12.07.2020 состояние идеальное все полный комплект документов гарантия чек... ',
#   'Мобильные телефоны » Huawei',
#   'Усть-Каменогорск',
#   '29 ноября 2020 г.',
#   '  25 '),
#  ('samsung s4 продажа',
#   '10 000 ₸',
#   'В хорошем состоянии , чехол - книжка .',
#   'Мобильные телефоны » Samsung',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  31 '),
#  ('Ищу телефоны, 2 айфон по подступным ценам',
#   '20 000 ₸',
#   'Главное что бы были в хорошем состоянии. Г Алматы \nТолько Айфоны',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  2 '),
#  ('Продам Xiaomi Pocophone F1',
#   '115 000 ₸',
#   'ОБМЕН НЕ ИНТЕРЕСУЕТ! НУЖНЫ ДЕНЬГИ!\n\nСмартфон в идеальном состоянии! Покупал в феврале 2019г за 160000 тг в Алмате.... ',
#   'Мобильные телефоны » Xiaomi',
#   'Тараз',
#   '29 ноября 2020 г.',
#   '  177 '),
#  ('Породам телефон Айфон 6',
#   '65 000 ₸',
#   '64 гб',
#   'Мобильные телефоны » Dex',
#   'Узынагаш',
#   '29 ноября 2020 г.',
#   '  80 '),
#  ('Samsung Galaxy J7 2016',
#   '35 000 ₸',
#   'Телефон в идеальном состоянии. С момента покупки Был в чехле и с защитным стеклом. В комплекте зарядка,2 чехла.... ',
#   'Мобильные телефоны » Samsung',
#   'Усть-Каменогорск',
#   '29 ноября 2020 г.',
#   '  154 '),
#  ('Айфон 6',
#   'Договорная цена',
#   'Продам айфон 6,6s телефоны в хорошем состоянии быстрым торг жду 87022953545',
#   'Мобильные телефоны » Apple',
#   'Уральск',
#   '29 ноября 2020 г.',
#   '  26 '),
#  ('IPhone 7 32gb',
#   '92 000 ₸',
#   'Продам iPhone 7 32gb, есть коцки по корпусу, сам телефон работает безупречно. Коробка имеется. Все вопросы по... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  127 '),
#  ('Смартфон',
#   '55 000 ₸',
#   'Продается смартфон Huawei Honor 10 lite. Смартфон в хорошем состоянии. Память 64гБ. Покупал в феврале 2020 года в... ',
#   'Мобильные телефоны » Huawei',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  128 '),
#  ('Lg k8',
#   '22 000 ₸',
#   'Продам Lg k8 в идеальном состоянии,с коробкой и документами',
#   'Мобильные телефоны » LG',
#   'Тараз',
#   '29 ноября 2020 г.',
#   '  136 '),
#  ('СРОЧНО! Айфон 6 плюс и Самсунг А5 2017',
#   '75 000 ₸',
#   'СРОЧНО! 2 телефона за 75, 000тг. Айфон 6 плюс 16гб и Самсунг А5 2017г. Оба телефона в отличном состоянии, рабочие.... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  21 '),
#  ('Samsung A5, 2017',
#   '35 000 ₸',
#   'Samsung A5, 2017г. 35, 000тг Срочно! В отличном состоянии, все работает идеально, 2 симки, без коробки, есть зарядное... ',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  48 '),
#  ('продам айфон 8+',
#   '140 000 ₸',
#   'Продам свой телефон срочно нужны деньги',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  2 '),
#  ('IPhone 6 Plus',
#   '40 000 ₸',
#   'Айфон 6 плюс, серый, 16гб за 40,000тг. Без коробки. Телефон оригинал, один хозяин, телефон отлично работает. Не... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  147 '),
#  ('Apple iPhone 6 64 Gb',
#   '50 000 ₸',
#   'Продаю iPhone 6, Silver 64 gb в хорошем состоянии, все работает. В наличий есть чехол, Samsung наушник, зарядка, и... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  332 '),
#  ('IOS iPhone 6 64 gb',
#   '50 000 ₸',
#   'Продаю iPhone 6, Silver 64 gb в хорошем состоянии, все работает. В наличий есть чехол, Samsung наушник, зарядка, и... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  294 '),
#  ('айфон 7 плюс 64 гб  все работает без минусов',
#   '110 000 ₸',
#   'Есть торг',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  22 '),
#  ('Продаю телефон Huawei y6 prime 2018',
#   '40 000 ₸',
#   'Продаю телефон Huawei очень в хорошем состаяний. Память 16гб в золотистым цвете.\nПричина продажи:хочу перетий с Huawei... ',
#   'Мобильные телефоны » Huawei',
#   'Усть-Каменогорск',
#   '29 ноября 2020 г.',
#   '  51 '),
#  ('Продам новый самсунг s20 ultra',
#   'Договорная цена',
#   'Продам абсолютно новый телефон.  Купила месяц назад. Состояние идеальное.  Память 128гб.  Если обмен только телефоны... ',
#   'Мобильные телефоны » Samsung',
#   'Атырау',
#   '29 ноября 2020 г.',
#   '  161 '),
#  ('Продам iPhone SE',
#   '100 000 ₸',
#   'Продам айфон SE полный комплект в отличном состоянии. 32гб',
#   'Мобильные телефоны » Apple',
#   'Тараз',
#   '29 ноября 2020 г.',
#   '  1484 '),
#  ('Самсунг а5 2017г Samsung a5 срочна сатылады',
#   '30 000 ₸',
#   'Телефон жакнда алдым багасын келсемиз тел алмай жатсам',
#   'Мобильные телефоны » Samsung',
#   'Жапек батыр',
#   '29 ноября 2020 г.',
#   '  26 '),
#  ('Продам Самсунг',
#   'Договорная цена',
#   'Самсунг J7 2016 года очень прост в использовании и удобен как телефон.\nТак же он тянет игры на фул hg \nПамять 16г. +... ',
#   'Мобильные телефоны » Samsung',
#   'Усть-Каменогорск',
#   '29 ноября 2020 г.',
#   '  19 '),
#  ('Apple S 6+',
#   '60 000 ₸',
#   'Айфон S 6+  продам почти новые пользовался месяц в хорошем состоянии есть один минус  по корпусу продам либо Обмен',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  0 '),
#  ('Самсунг галакси А 3. 2017гв',
#   '40 000 ₸',
#   'Самсунг галакси А3. 2017 гв. В отличном состояний. Документы 100%',
#   'Мобильные телефоны » Samsung',
#   'Кызылорда',
#   '29 ноября 2020 г.',
#   '  10 '),
#  ('Продается J7(2016)',
#   '30 000 ₸',
#   'Качество:Идеальное; Использовалось только для работы',
#   'Мобильные телефоны » Samsung',
#   'Атырау',
#   '29 ноября 2020 г.',
#   '  17 '),
#  ('Продается J7(2016)',
#   '35 000 ₸',
#   'Качество:Идеальное; Использовалось только для работы',
#   'Мобильные телефоны » Samsung',
#   'Атырау',
#   '29 ноября 2020 г.',
#   '  2 '),
#  ('Продается J7(2016) 16гб + 8гб',
#   '30 000 ₸',
#   'Состояние идеальное',
#   'Мобильные телефоны » Samsung',
#   'Атырау',
#   '29 ноября 2020 г.',
#   '  19 '),
#  ('Продается J7(2016) 16гб + 8гб',
#   '35 000 ₸',
#   'Состояние идеальное',
#   'Мобильные телефоны » Samsung',
#   'Атырау',
#   '29 ноября 2020 г.',
#   '  22 '),
#  ('iPhone 11',
#   '280 000 ₸',
#   'Память 64Гб. Телефон в идеальном состоянии. Не ремонтировался .',
#   'Мобильные телефоны » Apple',
#   'Сатпаев',
#   '29 ноября 2020 г.',
#   '  9 '),
#  ('Сотка сатам',
#   'Договорная цена',
#   'А51 сатылады жагдайы оте жаксы багасы 100мын келисемиз ном:',
#   'Мобильные телефоны » Samsung',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  36 '),
#  ('Samsung J7 2016 сатамын',
#   '30 000 ₸',
#   'Возможен торг.',
#   'Мобильные телефоны » Samsung',
#   'Атырау',
#   '29 ноября 2020 г.',
#   '  23 '),
#  ('iPhone SE2020,black,64GB',
#   '160 000 ₸',
#   'Телефон в идиальном сост,почти новый,царапин нет,3 месяца назад покупал.',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  29 '),
#  ('Телефон-UMIDIGI A7Pro 6, 3/16мр/4150мА-ч/64 ГБ/ 8яд.',
#   '59 990 ₸',
#   'Продам новый телефон\nОС: Стоковая Android 10. 0\nSIM-карта: Dual Nano SIM\nКамеры Quad Camera (16MP + 16MP + 5MP) +... ',
#   'Мобильные телефоны » Другой',
#   'Усть-Каменогорск',
#   '29 ноября 2020 г.',
#   '  101 '),
#  ('IPhone 7 256Gb',
#   '90 000 ₸',
#   'Продаю IPhone 7 Jet Black в хорошем состоянии. Память 256 гб, куплен в магазине Sulpak. Все кнопки работают, телефон... ',
#   'Мобильные телефоны » Apple',
#   'Актобе',
#   '29 ноября 2020 г.',
#   '  28 '),
#  ('Продам Appel 6s срочно продам',
#   '37 000 ₸',
#   'Продам Appel 6s в комплекте только документы и коробка. работает идеально',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  16 '),
#  ('Samsung galaxy s6 edge IPhone 6s',
#   '45 000 ₸',
#   'Продам \nSamsung galaxy s6 edge \nВ идеале без минусов\nКоробка, зарядка\nЦена 40 без торгa\nApple Iphone 6s rose gold\nВ... ',
#   'Мобильные телефоны » Apple',
#   'Темиртау',
#   '29 ноября 2020 г.',
#   '  27 '),
#  ('Продам А51 6/128',
#   '110 000 ₸',
#   'Телефону вторые сутки, с первого дня стоит чехол и 3d стекло, покупал за 108700 + 4500 за аксессуары, почти не... ',
#   'Мобильные телефоны » Samsung',
#   'Павлодар',
#   '29 ноября 2020 г.',
#   '  1 '),
#  ('Samsung Note Edge',
#   '20 000 ₸',
#   'Продаётся Samsung Note Edge на восстановление или на запчасти.',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  1279 '),
#  ('Продаю Samsung Galaxy A9 в отличном состоянии',
#   '70 000 ₸',
#   'тип моноблок (классический);\n\nAndroid 8.0;\n\nподдержка двух SIM-карт;\n\nэкран 6.3", разрешение 2220x1080;\n\nкамера 24... ',
#   'Мобильные телефоны » Samsung',
#   'Караганда',
#   '29 ноября 2020 г.',
#   '  320 '),
#  ('Самсунг галакси А 3 2017гв',
#   '40 000 ₸',
#   'Самсунг галакси А 3 2017гв',
#   'Мобильные телефоны » Samsung',
#   'Кызылорда',
#   '29 ноября 2020 г.',
#   '  17 '),
#  ('Мини телефон нокия l8star bm10',
#   '6 990 ₸',
#   'Продаю оптом и в розницу мини телефон.\nОтправка по всему Казахстану.\nДоставка по Алмате 500-1000 тг\nЖеке және көтерме... ',
#   'Мобильные телефоны » Nokia',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  15 '),
#  ('Телефон хуавей Y5',
#   '30 000 ₸',
#   '4 месяца назад купили, ещё в гарантии. Продаю в связи безнадобности.',
#   'Мобильные телефоны » Huawei',
#   'Уральск',
#   '29 ноября 2020 г.',
#   '  14 '),
#  ('Нокия 105',
#   '6 990 ₸',
#   'Продаю оптом и в розницу телефоны.\nДоставка пг Алмате от 500 тг\nА также могу отправить по всему Казахстану через... ',
#   'Мобильные телефоны » Nokia',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  7 '),
#  ('Продам смартфон',
#   '58 000 ₸',
#   'Продам смартфон в идеальном состоянии, нет царапин, модель Samsung A-40',
#   'Мобильные телефоны » Samsung',
#   'Усть-Каменогорск',
#   '29 ноября 2020 г.',
#   '  12 '),
#  ('Продаётся А 20',
#   '32 000 ₸',
#   'Продаётся А 20 состояние нормально',
#   'Мобильные телефоны » Samsung',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  14 '),
#  ('Самсунг S8+',
#   'Договорная цена',
#   'Продам телефон Самсунг S8+ 64гб состояние средняя с коробкой остальные вопросы по телефону',
#   'Мобильные телефоны » Samsung',
#   'Тараз',
#   '29 ноября 2020 г.',
#   '  41 '),
#  ('IPhone XS Max 256gb Gold',
#   'Договорная цена',
#   'Продам iPhone XS Max 256gb Gold.\nВ отличном состоянии. Есть один минус, видно на фото писать в ЛС.\nЦена 270.... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  62 '),
#  ('Продам смартфон poco x3 NFC',
#   '90 000 ₸',
#   'Телефону менее месяца\nОбмен с доплатой интересует \nХлам не предлагать \nДокументы и гарантия есть \nЦена в магазине... ',
#   'Мобильные телефоны » Xiaomi',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  49 '),
#  ('Срочно Продам Poco X3 NFC',
#   '90 000 ₸',
#   'Телефону менее месяца\nОбмен с доплатой интересует \nХлам не предлагать \nДокументы и гарантия есть \nЦена в магазине... ',
#   'Мобильные телефоны » Xiaomi',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  41 '),
#  ('Продам смартфон poco x3 NFC',
#   '90 000 ₸',
#   'Телефону менее месяца\nОбмен с доплатой интересует \nХлам не предлагать \nДокументы и гарантия есть \nЦена в магазине... ',
#   'Мобильные телефоны » Xiaomi',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  28 '),
#  ('iPhone 6s 64gb space gray',
#   '67 000 ₸',
#   'Продам iPhone 6s 64gb space gray, в очень хорошем состоянии. Реальному покупателю торг.',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  1 '),
#  ('Продам телефон Samsung galaxy 12 гб',
#   '9 000 ₸',
#   'Телефон в отличном состояние, пользовался 2 месяца а так лежал не нужный пока не решыл продать, продаю 9,000 скидка в... ',
#   'Мобильные телефоны » Samsung',
#   'Павлодар',
#   '29 ноября 2020 г.',
#   '  34 '),
#  ('Xiaomi Redmi 9A',
#   '45 000 ₸',
#   'Новый xiaomi redmi A в идеале с коробкой и с документами как пришел так и стоит коробку еще не открывал хороший... ',
#   'Мобильные телефоны » Xiaomi',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  1 '),
#  ('IPhone 8',
#   '88 000 ₸',
#   'iPhone 8 \nВ комплекте есть только зарядчик и наушник\nРемонте не был \nЕмкость 99%\nEAC RM\nОкончательная цена\nСзади есть... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  6 '),
#  ('Продам AirPods 2 100% Оригинал. Полный комплект',
#   '50 000 ₸',
#   'Продам наушники беспроводные Apple AirPods. Куплены 6 месяц назад в Меломане, продаю в связи с покупкой Apple AirPods... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  3 '),
#  ('Продам Samsung A3 16Gb Black 2-Sim',
#   '25 000 ₸',
#   'Продам смартфон Самсунг A3 (2016) в отличном (идеальный) в рабочем состоянии. Очень бережно эксплуатировался, сколов,... ',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  5 '),
#  ('Продам Iphone SE',
#   '25 000 ₸',
#   'По состоянию можно сказать что ему 6/10 и меньше, снаружи покоцан, так по функционалу нету равного',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  87 '),
#  ('Hts e8',
#   '12 000 ₸',
#   'Е8 hts в отличном состояний все работает но не видит сим',
#   'Мобильные телефоны » HTC',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  18 '),
#  ('iPhone 6',
#   '50 000 ₸',
#   'Продам iPhone 6 в хорошем состоянии, рабочий\nВ комплекте чехол',
#   'Мобильные телефоны » Apple',
#   'Павлодар',
#   '29 ноября 2020 г.',
#   '  29 '),
#  ('айфон 12 про Макс 256 золотой новый',
#   '680 000 ₸',
#   'Телефон новый не распечатанный , ставил на него бронь месяц назад ещё поступил только вчера с магазина забрал но из-за... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  9 '),
#  ('Телефон',
#   '10 000 ₸',
#   'Телефон SONY XPERIA. В рабочем состоянии, всё работает.',
#   'Мобильные телефоны » Sony',
#   'Костанай',
#   '29 ноября 2020 г.',
#   '  442 '),
#  ('Телефон',
#   '30 000 ₸',
#   'Продам телефон ASUS.',
#   'Мобильные телефоны » ASUS',
#   'Костанай',
#   '29 ноября 2020 г.',
#   '  352 '),
#  ('Продам meizu C9',
#   '18 000 ₸',
#   'Продам Meizu C9: 4G, 16гб \nТелефон абсолютно новый, со всей комплектацией.\nБЕЗ МИНУСОВ.\nДокументы, коробка, зарядка.... ',
#   'Мобильные телефоны » Meizu',
#   'Павлодар',
#   '29 ноября 2020 г.',
#   '  1 '),
#  ('Срочно!!! продам телефон Samsung Galaxy a516/128Gb,',
#   '85 000 ₸',
#   'Срочно! Продам телефон за 80000-75000\n•Samsung Galaxy a51 128Gb, цвет черный\n•Смартфон на платформе... ',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  63 '),
#  ('Sony experia',
#   'Договорная цена',
#   '',
#   'Мобильные телефоны » Sony',
#   'Караганда',
#   '29 ноября 2020 г.',
#   '  226 '),
#  ('iphone 7,32Gb',
#   'Договорная цена',
#   'Продается iphone 7\nСостояние хорошое\nПамять 32 gb\nна фото на экране плёнка \nэкран не менялся,свой родной\nВозможен торг',
#   'Мобильные телефоны » Apple',
#   'Узынагаш',
#   '29 ноября 2020 г.',
#   '  53 '),
#  ('Продам смартфон',
#   '35 000 ₸',
#   'Продам смартфон Samsung Galaxy A01 Core. Новый в коробке с документами. Цена 35 000. Тел',
#   'Мобильные телефоны » Samsung',
#   'Костанай',
#   '29 ноября 2020 г.',
#   '  25 '),
#  ('Samsung A10',
#   '45 000 ₸',
#   'Новый Самсунг А10 с коробкой с документами в идеальном состояний как пришел так и стоит коробку даже не открывал. Торг... ',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  4 '),
#  ('Телефон сатам экрандары күйгенба блмим j5 a5 екеуі',
#   'Договорная цена',
#   'Телефон сатам экрандары күйгенба блмим j5 a5 екеуі 10к \nЭкраны жанбайды',
#   'Мобильные телефоны » Samsung',
#   'Тараз',
#   '29 ноября 2020 г.',
#   '  4 '),
#  ('Meizu M6 Note 16 Gb',
#   '40 000 ₸',
#   'Продам телефон в отличном состоянии. Был приобретен в декабре 2018 года. Коробка, чехол, защитное стекло в наличии.',
#   'Мобильные телефоны » Meizu',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  1093 '),
#  ('Продам Самсунг А10 и редми 9А в идельном состояний новый с коробкой',
#   'Договорная цена',
#   'Новый с документами Самсунг 10 и Редми 9А\nСамсунг А10 - 40000тнг есть торг\nРедми 9А - 400000тнг так же есть торг\nОба... ',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  5 '),
#  ('HTC Desire 326G dual sim',
#   '20 000 ₸',
#   'Cмартфон с Android 4.4, поддержка двух SIM-карт, экран 4.5", камера 8 МП, автофокус, память 8 ГБ, слот для карты... ',
#   'Мобильные телефоны » HTC',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  180 '),
#  ('HTC Desire 326G dual sim',
#   '20 000 ₸',
#   'Cмартфон с Android 4.4, поддержка двух SIM-карт, экран 4.5", камера 8 МП, автофокус, память 8 ГБ, слот для карты... ',
#   'Мобильные телефоны » HTC',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  180 '),
#  ('Продам телефон',
#   '20 000 ₸',
#   'Продается телефон LG K10 в идеальном состоянии. Так как подарили другой телефон. Документ и коробка имеется. Наушники... ',
#   'Мобильные телефоны » LG',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  58 '),
#  ('Продам Iphone 5s 32gb',
#   '30 000 ₸',
#   'Продам Iphone 5s сост среднее, все работает, заменена батарея, точ ид тоже работает, куплен в Германий, состояние на... ',
#   'Мобильные телефоны » Apple',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  98 '),
#  ('IPhone 12 64гб Чёрный Цвет',
#   'Договорная цена',
#   'Жаңадан алынған қолданылмаған але',
#   'Мобильные телефоны » iNew',
#   'Сарыагаш',
#   '29 ноября 2020 г.',
#   '  39 '),
#  ('Телефон нокиа N97 и N73',
#   '5 000 ₸',
#   'Продам 2 телефона на запчасти N97 и N73',
#   'Мобильные телефоны » Nokia',
#   'Уральск',
#   '29 ноября 2020 г.',
#   '  145 '),
#  ('Телефон Samsung galaxy j 5',
#   '55 000 ₸',
#   'Телефон Samsung galaxy j 5 Prime новый долго не использовали зарятка всё ест 55. 000 могу за 50. 000',
#   'Мобильные телефоны » Samsung',
#   'Атырау',
#   '29 ноября 2020 г.',
#   '  49 '),
#  ('Смартфон xiaomi Mi 9Lite. 6/64gb. Черный',
#   '85 000 ₸',
#   'Продам смарт. Xiaomi Mi 9Lite. Black. Память 6гб озу. 64гб.осн п. Все в хорошем состояний. Работает .докуметы есть... ',
#   'Мобильные телефоны » Xiaomi',
#   'Атырау',
#   '29 ноября 2020 г.',
#   '  56 '),
#  ('Samsung Galaxy A70. A90 Replica',
#   '33 000 ₸',
#   'Samsung Galaxy A70. A90 Replica копия\nЮжнокорейские КОПИЯ 100% ный\nВ наличии все цвета',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  2900 '),
#  ('Samsung Galaxy Note 10 Galaxy S10+ Replica',
#   '45 000 ₸',
#   'Samsung Galaxy Note 10\nSamsung Galaxy S10 Plus\n\nREPLICA Точная КОПИЯ\n\nЕсть доставка по РК',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  8410 '),
#  ('Samsung Galaxy А70.J5. J6. J7+ Точная КОПИЯ',
#   '37 000 ₸',
#   'Samsung Galaxy А60.А70.J5. J6. J7+ Replica КОПИЯ\n\nЕсть Доставка по РК\nВ подарок чехол стекло',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  1595 '),
#  ('Доставка РК Samsung Galaxy a30',
#   '53 000 ₸',
#   'Процессор: восьмиядерный (1.8 ГГц, 1.6 ГГц)\n\nЭкран: 6,4 дюймовый (162,1 мм)⁵ Full HD+ sAMOLED\n\nОсновная камера... ',
#   'Мобильные телефоны » Samsung',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  16 '),
#  ('Продам IPhone 11 64Gb Yellow.Полный комплект',
#   '275 000 ₸',
#   'Продам IPhone 11 64 Gb Yellow EAC, официальный.Куплен в магазине Ipoint. Телефон как новый с магазина все документы и... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  0 '),
#  ('Poco F1',
#   '70 000 ₸',
#   'Сатылады сост жаксы 128 гб обмен жок',
#   'Мобильные телефоны » Xiaomi',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  1 '),
#  ('Смартфон Huawei Y6 2019 синий\n\n\xa0(396',
#   '46 000 ₸',
#   'Новый, не распоковонный, чек, гарантия и все документы в наличии.',
#   'Мобильные телефоны » Huawei',
#   'Петропавловск',
#   '29 ноября 2020 г.',
#   '  1 '),
#  ('LG G6',
#   '60 000 ₸',
#   'Lg g6 продам, цена договорная',
#   'Мобильные телефоны » LG',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  207 '),
#  ('Айфон 8 64гб',
#   '135 000 ₸',
#   'Айфон 8 64гб почти новая пользовались 1 неделю. Сост батареи 99%. Комплектация коробка и зарядчик.Срочно',
#   'Мобильные телефоны » Apple',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  2 '),
#  ('Продам айфон',
#   'Договорная цена',
#   'Продам айфон 5, нормальное рабочее состояние, батарея держит заряд, всё функционирует, один минус барахлит задняя... ',
#   'Мобильные телефоны » Apple',
#   'Кокшетау',
#   '29 ноября 2020 г.',
#   '  26 '),
#  ('IPhone XS Max 256гб(золотистый)',
#   '170 000 ₸',
#   'Продам ! Задняя панель разбита на работу никак не влияет !\nРаботает отлично',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  101 '),
#  ('IPhone 4S',
#   '10 000 ₸ \n                                    Срочно, торг\n                                ',
#   'Продам IPhone 4S 8Gb, состояние отличное, защитное стекло, четыре чехла, коробка, документы, кабель и блок питания не... ',
#   'Мобильные телефоны » Apple',
#   'Костанай',
#   '29 ноября 2020 г.',
#   '  527 '),
#  ('Продам смартфон',
#   '7 500 ₸',
#   'Продам смартфон китай модель С4, интернет 2 джи Е, память мало 150мб. Камера, видео, флешка. 2 симкарты, с плёнкой... ',
#   'Мобильные телефоны » MyPhone',
#   'Капчагай',
#   '29 ноября 2020 г.',
#   '  319 '),
#  ('Продам смартфон',
#   '5 500 ₸',
#   'Продам смартфон есть трещина, модель бенефит С 504, 2 симкарты, интернет 3джи, память 4гб, камера, видео, флешка.',
#   'Мобильные телефоны » Другой',
#   'Капчагай',
#   '29 ноября 2020 г.',
#   '  377 '),
#  ('Lg q7 и iPhone 5S',
#   '60 000 ₸',
#   'Продам 2 телефона. Lg-2018 года выхода. Есть нфс, быстраЯ зарядка, Но есть один минус есть трещины. IPhone 5S-2013... ',
#   'Мобильные телефоны » LG',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  5 '),
#  ('Продам сенсорный телефон',
#   '20 000 ₸',
#   'Продам телефон Huawei y 5 prime.\nГод 2018.\n-Безрамочный экран Huawei FullView.\n-Батарея 3020 мА*ч*\n-2 гб RAM/16гб... ',
#   'Мобильные телефоны » Huawei',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  0 '),
#  ('Продам телефон',
#   '45 000 ₸',
#   'Продам телефон в отличном состоянии ещё на гарантии,без царапин и потёртостей,документы все есть,зарядку держит... ',
#   'Мобильные телефоны » OPPO',
#   'Караганда',
#   '29 ноября 2020 г.',
#   '  55 '),
#  ('Iphone 5s',
#   '40 000 ₸',
#   'Продаётся айфон 5 s. 16 ГБ. В отличном состоянии. \n•НЕ ЗАВИСАЕТ\n•Нет ни царапины\n•Есть защитный стекло \n•Есть... ',
#   'Мобильные телефоны » Apple',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  406 '),
#  ('Смартфон',
#   '15 000 ₸',
#   'Оригинальный смартфон.',
#   'Мобильные телефоны » Nokia',
#   'Кокшетау',
#   '29 ноября 2020 г.',
#   '  559 '),
#  ('Продам сенсорный телефон',
#   '20 000 ₸',
#   'Продам телефон Huawei y 5 prime.\nГод 2018.\n-Безрамочный экран Huawei FullView.\n-Батарея 3020 мА*ч*\n-2 гб RAM/16гб... ',
#   'Мобильные телефоны » Huawei',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  1 '),
#  ('iPhone 7',
#   '75 000 ₸',
#   'Срочно продам телефон iPhone 7 128gb чёрный цвет \nСостояние отлично все работает \nОтпечаток пальца работает \nКомплекте... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  6 '),
#  ('Телефон',
#   '120 000 ₸',
#   'Новый айфон 7 черного цвета,не пользовались как купили так и лежит,красный чехол',
#   'Мобильные телефоны » Apple',
#   'Актау',
#   '29 ноября 2020 г.',
#   '  1 '),
#  ('Телефон',
#   'Договорная цена',
#   'Oppo a5 обменяю на Айфон 7+',
#   'Телефоны, гаджеты » Мобильные телефоны',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  65 '),
#  ('Телефон обменяю айфон6 на айфон 7 плюс доплата',
#   'Договорная цена',
#   'Обменяю Айфон 6, на Айфон 7 плюс доплата',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  155 '),
#  ('Продам сенсорный телефон',
#   '20 000 ₸',
#   'Продам телефон Huawei y 5 prime.\nГод 2018.\n-Безрамочный экран Huawei FullView.\n-Батарея 3020 мА*ч*\n-2 гб RAM/16гб... ',
#   'Мобильные телефоны » Huawei',
#   'Нур-Султан (Астана)',
#   '29 ноября 2020 г.',
#   '  2 '),
#  ('Обменяю айфон 6 на X box',
#   '11 111 ₸',
#   'Б/у',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  56 '),
#  ('Samsung A21 32Gb',
#   'Договорная цена',
#   'Продаётся Samsung A21. Новый, в коробке со всеми аксессуарами.',
#   'Мобильные телефоны » Samsung',
#   'Шымкент',
#   '29 ноября 2020 г.',
#   '  27 '),
#  ('Телефон Huawei P8 Lite',
#   '23 999 ₸',
#   'Huawei P8 Lite 16Gb\nТелефон в хорошем техническом состоянии 9/10\nВ комплекте только коробка\nЦена окончательная, обмена... ',
#   'Мобильные телефоны » Huawei',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  43 '),
#  ('Продам телефон',
#   '70 000 ₸',
#   'Продам А21 ещё новый',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  71 '),
#  ('Samsung A8',
#   'Договорная цена',
#   'Samsung A8 ды Айфон 6 или айфон 7 ге ауыстрам Жагдайы жаксы 4G устайд 2 симкарта салынады сотка кумайд \nНо 1 гана... ',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '29 ноября 2020 г.',
#   '  8 '),
#  ('Продаю Айфон',
#   'Договорная цена',
#   'Продаю IPhone XR 64 гб за 230 тысяч Пользовалась пол года. Состояние идеальное, без царапин без нарекании Ничего не... ',
# ...
#   '  78 '),
#  ('IPhone 8 Plus 128g',
#   '265 000 ₸',
#   'Продам IPhone 8 Plus 128g\niOS 14.1\nЦвет: space gray\nТелефон новый пользовался меньше месяца(покупал с нуля) есть... ',
#   'Мобильные телефоны » Apple',
#   'Павлодар',
#   '28 ноября 2020 г.',
#   '  21 '),
#  ('Продам телефон.Oppo A5 ,2019 года.60 к',
#   '60 000 ₸',
#   'Продам телефон,так как купила новый.\nOppo A5 ,2019 года.\n60к,торг уместен.\nБез трещин, без царапин, состояние... ',
#   'Мобильные телефоны » OPPO',
#   'Кокшетау',
#   '28 ноября 2020 г.',
#   '  14 '),
#  ('Айфон 5s',
#   '40 000 ₸',
#   'Срочноо!Продам айфон 5s в рабочем состоянии и в хорошем состоянии, +чехол,звоните..пишите....',
#   'Мобильные телефоны » Apple',
#   'Шымкент',
#   '28 ноября 2020 г.',
#   '  228 '),
#  ('iPhone 7 red 128 gb',
#   '100 000 ₸',
#   'Состояние 9.5/10, полный комплект все в оригинале, в ремонте не был, один хозяин, любые проверки',
#   'Мобильные телефоны » Apple',
#   'Караганда',
#   '28 ноября 2020 г.',
#   '  15 '),
#  ('Nokia 7230',
#   '12 000 ₸',
#   'Nokia 7230 оригинал (Венгрия) состояние 👌 багасы 12000',
#   'Мобильные телефоны » Nokia',
#   'Актау',
#   '28 ноября 2020 г.',
#   '  11 '),
#  ('Продаётся  айфон  6s',
#   '90 000 ₸',
#   'Состояние отличное, практически не пользовались. Куплен 18. 08. 2020 году 30 130000. Все документы имеются.',
#   'Мобильные телефоны » Apple',
#   'Тараз',
#   '28 ноября 2020 г.',
#   '  15 '),
#  ('iPhone 7 32GB',
#   '95 000 ₸',
#   'Хорошая состояние. Коробка имеется. Торг есть.',
#   'Мобильные телефоны » Apple',
#   'Шымкент',
#   '28 ноября 2020 г.',
#   '  177 '),
#  ('Oppo a5s',
#   '55 000 ₸',
#   'Прадам OPPO a5s 32 gb Отпечаток роботает✅\nНе гонит✅ \nПрадам или обмен✅\nПолный комплект✅\nЦена 55.000\nОбмен только Айфон... ',
#   'Мобильные телефоны » OPPO',
#   'Семей',
#   '28 ноября 2020 г.',
#   '  247 '),
#  ('телефон',
#   '5 000 ₸',
#   'Отдам самсунг ж 4 побывал в воде надо делать или сушить есть трещинки память 3. 32',
#   'Мобильные телефоны » Samsung',
#   'Усть-Каменогорск',
#   '28 ноября 2020 г.',
#   '  495 '),
#  ('Редми 6 а',
#   '18 000 ₸',
#   'Редми 6 а',
#   'Мобильные телефоны » Xiaomi',
#   'Усть-Каменогорск',
#   '28 ноября 2020 г.',
#   '  161 '),
#  ('Продам LG k10',
#   '10 000 ₸',
#   'Продам телефон рабочий чуть чуть разбит, но это плёнка звонить или писать сюда.',
#   'Мобильные телефоны » LG',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  66 '),
#  ('Продам телефон  G-5 в хор сост',
#   '35 000 ₸',
#   'Продам Самсунг G-5 чистый коробки зарядки нет',
#   'Мобильные телефоны » Samsung',
#   'Талдыкорган',
#   '28 ноября 2020 г.',
#   '  3 '),
#  ('Продам телефон',
#   '5 000 ₸',
#   'Продам тилефоны рабочие. Верх по 5000, низ По3000. Торг обмен на сенсорный.',
#   'Мобильные телефоны » Nokia',
#   'Павлодар',
#   '28 ноября 2020 г.',
#   '  51 '),
#  ('продам телефон',
#   '50 000 ₸',
#   'Состояние отличное',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  11 '),
#  ('Продам Самсунг',
#   '10 000 ₸',
#   'Мощ. Хороший отличный',
#   'Мобильные телефоны » Samsung',
#   'Тараз',
#   '28 ноября 2020 г.',
#   '  9 '),
#  ('Redmi s2',
#   '32 000 ₸',
#   'Redmi s2\nСостоение хороший\nКорапка жок удв копия берем\nБагасы келисиммен\nЦена 32000',
#   'Мобильные телефоны » Xiaomi',
#   'Шымкент',
#   '28 ноября 2020 г.',
#   '  13 '),
#  ('aifon 6s',
#   '45 000 ₸',
#   'срочно продам айфон 6s сост хорощий все работает',
#   'Мобильные телефоны » Apple',
#   'Актобе',
#   '28 ноября 2020 г.',
#   '  13 '),
#  ('Продаётся самсунг А6',
#   '50 000 ₸',
#   'Продаётся телефон А6. 32 гб. Состояния хорошее. Царапин нет. + 2 чехла, и зарядка.',
#   'Мобильные телефоны » Samsung',
#   'Сарыкемер',
#   '28 ноября 2020 г.',
#   '  13 '),
#  ('IPhone 5S 64GB',
#   '30 000 ₸',
#   'IPhone 5S 64GB с коробкой и зарядкой в комплекте.',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  16 '),
#  ('Продаётся  Samsung galaxy A31',
#   '85 000 ₸',
#   'Продаётся Новый хароший Телефон в Хорошом состояний Samsung galaxy A31  Телефон в Белом Цвете 4ГБ Внутрений Памяти... ',
#   'Мобильные телефоны » Samsung',
#   'Туркестан',
#   '28 ноября 2020 г.',
#   '  76 '),
#  ('Мобильный телефон',
#   'Договорная цена',
#   'Почти как новый',
#   'Мобильные телефоны » Другой',
#   'Аягоз',
#   '28 ноября 2020 г.',
#   '  4 '),
#  ('Продам айфон 6',
#   'Договорная цена',
#   'Продам айфон 6 минусы сеть не ловит отпечаток фонарик вспышка не работает пишите',
#   'Мобильные телефоны » Apple',
#   'Павлодар',
#   '28 ноября 2020 г.',
#   '  12 '),
#  ('Xiaomi Redmi Note 8 Pro 128',
#   '75 000 ₸',
#   'Продам 8 Про 128 гигабайт белого цвета.\nВ комплекте зарядка, 3 чихла, коробка с документами. \nТелефон в отличном... ',
#   'Мобильные телефоны » Xiaomi',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  19 '),
#  ('Продам или обменяю редми 8А 2/32гб',
#   '35 000 ₸',
#   'Обменяю редми 8А 2/32гб, в идеале с зарядкой с двумя чехлами но без документов! На редми ноут 7 или редми 8про с моей... ',
#   'Мобильные телефоны » Xiaomi',
#   'Костанай',
#   '28 ноября 2020 г.',
#   '  7 '),
#  ('Смартфон OnePlus 3T черный',
#   '125 000 ₸',
#   'В отличном состоянии, евроверсия. \nОчень быстрый. \nВстроенная память - 64 Гб. \nОперативная память - 6 Гб. \n2 симки.... ',
#   'Мобильные телефоны » Другой',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  19064 '),
#  ('iPhone 8 64GB',
#   '170 000 ₸',
#   '•iPhone 8 (оригинал)\n•Память-64GB\n•В идеальном состояние\n•Полная комплектация: •(коробка, документы, гарант. Талон.... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  88 '),
#  ('IPhone 8 64GB',
#   '170 000 ₸',
#   '•iPhone 8 (оригинал)\n•В идеальном состояние\n•Полная комплектация: •(коробка, документы, гарант. Талон. Зарядка,... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  195 '),
#  ('Самсунг j5. 6',
#   '35 000 ₸',
#   'Самсунг j5. 6 в идеальном состоянии',
#   'Мобильные телефоны » Samsung',
#   'Кызылорда',
#   '28 ноября 2020 г.',
#   '  30 '),
#  ('Продам телефон',
#   '35 000 ₸',
#   'Продам тел Самсунг j5. 6 в идеальном состоянии',
#   'Мобильные телефоны » Samsung',
#   'Кызылорда',
#   '28 ноября 2020 г.',
#   '  26 '),
#  ('продам сотовый телефон',
#   '20 000 ₸',
#   'Продам сот телефон в отличном состояние.',
#   'Мобильные телефоны » Huawei',
#   'Жанаозен',
#   '28 ноября 2020 г.',
#   '  4 '),
#  ('Самсунг s9',
#   '100 000 ₸',
#   'В идеальном состоянии с документами +номер обмен на s20 (С20) с документами обязательно с моей доплатой',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  37 '),
#  ('продам телефон Самсунг А50',
#   'Договорная цена',
#   'Продам телефон Самсунг А50, в идеальном состоянии, сама покупала в Мае, коробка-оригинал наушники-зарядка все имеется,... ',
#   'Мобильные телефоны » Acer',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  77 '),
#  ('Iphone 7',
#   '65 000 ₸',
#   'Iphone 7\n32 gb',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  49 '),
#  ('Продаётся телефон J3',
#   '45 000 ₸',
#   'Телефон J3 состояние хорошее. 16 гб. + чехол есть - зарядки нет. чёрный цвет',
#   'Мобильные телефоны » Samsung',
#   'Сарыкемер',
#   '28 ноября 2020 г.',
#   '  12 '),
#  ('Телефон на запчасти',
#   '3 000 ₸',
#   'Телефон, Samsung, черного цвета.',
#   'Мобильные телефоны » Другой',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  813 '),
#  ('iPhone 7 black',
#   'Договорная цена',
#   'Память : 32 гб\nСостояние идеальное! \nКоробка, зарядка, наушники все имеется!\nВсе родное ничего не менял!\n+3 чехла в... ',
#   'Мобильные телефоны » Другой',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  14 '),
#  ('Продам Айфон 5S, цвет Space Gray, 16 GB',
#   '20 000 ₸',
#   'Телефон в отличном состоянии. Возможен торг.',
#   'Мобильные телефоны » Apple',
#   'Актобе',
#   '28 ноября 2020 г.',
#   '  96 '),
#  ('Продам телефон в хорошем состояний',
#   'Договорная цена',
#   'Срочно продам телефон в хорошем состоянийLand Rover две симкарты флейта микро зарядка самсунг фонарик вообще ослепляет... ',
#   'Мобильные телефоны » Другой',
#   'Актау',
#   '28 ноября 2020 г.',
#   '  16 '),
#  ('Samsung Galaxy A7',
#   '55 000 ₸',
#   'Samsung Galaxy A7 2017 32GB с коробкой и зарядкой в комплекте. Флешка на 64GB в подарок.',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  7 '),
#  ('Продам iPhone XR 64 Gb White',
#   '220 000 ₸',
#   'Продам iPhone 64 Gb White в отличном состоянии. Полный комплект, наушники не использовались. В сервисе не был. Обмен... ',
#   'Мобильные телефоны » Apple',
#   'Актобе',
#   '28 ноября 2020 г.',
#   '  140 '),
#  ('Продам iPhone 5S она на блокировке пароль забыл',
#   '40 000 ₸',
#   'минуса нету на Айфоне всё хорошо',
#   'Мобильные телефоны » Apple',
#   'Шымкент',
#   '28 ноября 2020 г.',
#   '  43 '),
#  ('Айфон 6 Обмен',
#   'Договорная цена',
#   'Айфон 6 бар\nПамят 16гб\nЕмкость 77%\n43000деп жатрм\nБүгін ертен алатындарға 40000ка беріп жіберем.\nКомплект зарядка и 3... ',
#   'Мобильные телефоны » Apple',
#   'Шымкент',
#   '28 ноября 2020 г.',
#   '  12 '),
#  ('Продам Телефон Samsung A3',
#   '23 000 ₸',
#   'Продаю телефон: Samsung A3\n\nТелефон в рабочем состоянии. Нет никаких повреждений\n\nКамера отлично работает. Все... ',
#   'Мобильные телефоны » Samsung',
#   'Тараз',
#   '28 ноября 2020 г.',
#   '  23 '),
#  ('Добрый день срочно продам телефон',
#   '5 000 ₸',
#   'Продаю срочно двухсимочный телефон самсунг дуос состоянии хорошие по вопросу звоните торги есть',
#   'Мобильные телефоны » Samsung',
#   'Уральск',
#   '28 ноября 2020 г.',
#   '  439 '),
#  ('Телефон HUAWEL продам',
#   '35 000 ₸',
#   'Пролвм телефон, отпечаток работает, коробка имеется в отличном состояний',
#   'Мобильные телефоны » Huawei',
#   'Караганда',
#   '28 ноября 2020 г.',
#   '  13 '),
#  ('Samsung Galaxy J1 mini',
#   '2 000 ₸',
#   'Продам смартфон Samsung Galaxy J1 mini. Разбит экран, а так всё работает. Встроенная память (ГБ)\n8 ГБ.',
#   'Мобильные телефоны » Samsung',
#   'Актобе',
#   '28 ноября 2020 г.',
#   '  85 '),
#  ('продам телефон',
#   '2 000 ₸',
#   'Продам сотовый телефон Samsung Galaxy J1 (2016) на запчасти или же можно починить. Не работает экран.',
#   'Мобильные телефоны » Samsung',
#   'Актобе',
#   '28 ноября 2020 г.',
#   '  198 '),
#  ('Телефон',
#   '35 000 ₸',
#   '',
#   'Мобильные телефоны » Другой',
#   'Атырау',
#   '28 ноября 2020 г.',
#   '  18 '),
#  ('MyPhone',
#   'Договорная цена',
#   'Телефон в хорошом состояний в две углах есть царапины а так все чисто',
#   'Мобильные телефоны » MyPhone',
#   'Шымкент',
#   '28 ноября 2020 г.',
#   '  4 '),
#  ('Продам телефон HUAWEL Y7 2019',
#   '45 000 ₸',
#   'Надо поменять крышку, а так телефон нормальный',
#   'Мобильные телефоны » Huawei',
#   'Караганда',
#   '28 ноября 2020 г.',
#   '  8 '),
#  ('Прошивка устройств',
#   '2 000 ₸',
#   'Прошивка смартфонов на базе Android, обход Google блокировки, обход блокировки MI аккаунта, обход цифровых и... ',
#   'Мобильные телефоны » Другой',
#   'Щучинск',
#   '28 ноября 2020 г.',
#   '  14 '),
#  ('Продам раскладушку Samsung x460',
#   '9 000 ₸',
#   'Продаю старый телефон раскладушку Samsung x460 как раритет. Телефон работает, есть зарядка.',
#   'Мобильные телефоны » Samsung',
#   'Караганда',
#   '28 ноября 2020 г.',
#   '  173 '),
#  ('продам сот телефон на запчасть',
#   '5 000 ₸',
#   'Продам телефон престиж на запчасть',
#   'Мобильные телефоны » Prestigio',
#   'Актау',
#   '28 ноября 2020 г.',
#   '  11 '),
#  ('продам сот телефон на запчасть',
#   '5 000 ₸',
#   'Продам телефон престиж на запчасть',
#   'Мобильные телефоны » Prestigio',
#   'Актау',
#   '28 ноября 2020 г.',
#   '  11 '),
#  ('Nokia 6303',
#   '10 000 ₸',
#   '•Продам Nokia 6303 легендарная классика \n•Телефон в идеальном состоянии , в родном корпусе ничего не менялось все... ',
#   'Мобильные телефоны » Nokia',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  309 '),
#  ('IPhone 6',
#   '50 000 ₸',
#   'Iphone 6 32gb\nСост 10/10\nКоропка имеется \nНаушники оригинальные не открывались\nДокумент чек имеется\nОчень шустрый и не... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  4 '),
#  ('iPhone 6 32gb только обмен',
#   '35 000 ₸',
#   'iPhone 6 32gb только обмен',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  24 '),
#  ('Iphone 12 Pro Max из Германии',
#   '700 000 ₸',
#   'Вылетаю из Германии ориентировочно 10-13 декабря. Могу привести Iphone 12 Pro Max 256GB за 700к тг, своя цена 680к в... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  57 '),
#  ('Продаю iPhone 4s',
#   '15 000 ₸',
#   'Продаю iPhone 4 s,в очень хорошем состоянии,вместе с коробкой,с хорошим зарядным устройством,с встроенной сим картой.',
#   'Мобильные телефоны » Apple',
#   'Темиртау',
#   '28 ноября 2020 г.',
#   '  474 '),
#  ('IPhone X Айфон Х',
#   '180 000 ₸',
#   'Продам айфон х в идеальном состоянии не вскрывался все родное документы коробка зарядка царапин сколов нет обмен... ',
#   'Мобильные телефоны » Apple',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  107 '),
#  ('Срочно продам! IPhone 7 128 jet black',
#   '68 000 ₸',
#   'В отличном  состоянии, чехлы в подарок. Без коробки и комплекта. Есть минимальный торг.',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  431 '),
#  ('Samsung A80 телефон 128г',
#   '110 000 ₸',
#   'Продам телефон Samsung Galaxy A80 в отличном состоянии',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  25 '),
#  ('Samsung A10s 32gb',
#   '47 000 ₸',
#   'Всё харошым состояние каробка всё есть зарядка чехол отпечать ка все работаеть в экране зашитныи экран договаримся... ',
#   'Мобильные телефоны » Samsung',
#   'Нур-Султан (Астана)',
#   '28 ноября 2020 г.',
#   '  12 '),
#  ('Продается телефон j7 16 в хорошем состоянии все работает',
#   '20 000 ₸',
#   'Хоть он и б\\у зато в хорошем состоянии телефон постоянно в чехле противоударка тоже есть коробка имеется чехлы в... ',
#   'Мобильные телефоны » Samsung',
#   'Шымкент',
#   '28 ноября 2020 г.',
#   '  97 '),
#  ('Samsung j2 prime 2018',
#   '15 000 ₸',
#   'Samsung j2 prime, в очень хорошем состоянии. Есть коробка и зарядка. Куплен в декабре 2018 года. Продажа в связи с... ',
#   'Мобильные телефоны » Samsung',
#   'Петропавловск',
#   '28 ноября 2020 г.',
#   '  43 '),
#  ('Смартфоны',
#   '12 000 ₸',
#   'Продам айфон 5с всё работает только не видеть сим карту,возможно починить',
#   'Мобильные телефоны » Apple',
#   'Актау',
#   '28 ноября 2020 г.',
#   '  137 '),
#  ('Zte a601 4g',
#   '8 500 ₸',
#   'HD экран, 4g internet, батарея на 4000 mah(хватает на полтора дня).Состояние только из коробки. Коробка, зарядное... ',
#   'Мобильные телефоны » ZTE',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  50 '),
#  ('Samsung galaxy star plus',
#   '15 000 ₸',
#   'В хорошем состоянии. Самсунг отдам за 15000.',
#   'Мобильные телефоны » Samsung',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  60 '),
#  ('Новый Realmi c 3',
#   '36 000 ₸',
#   'Новый Realmi c3, с оригинальным чехлом, есть встроенная запись разговоров. Продам без торга за 36000тыс. Тенге. В... ',
#   'Мобильные телефоны » Другой',
#   'Семей',
#   '27 ноября 2020 г.',
#   '  267 '),
#  ('Iphone 6s',
#   '75 000 ₸',
#   'Iphone 6s в отличном состояний \nБез минусов, всегода носил в чехле, зашитной стекле\nНа ремонте не был, все родное.\nОт... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  8116 '),
#  ('Iphone 6s 32gb',
#   '75 000 ₸',
#   'Iphone 6s 32gb\nСостояние отличное\nВ комплекте каробка, документы, оригинальная зарядка, чехол \n80. 000тг',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  4255 '),
#  ('Продаю Самсунг А 3',
#   '32 000 ₸',
#   'Продаю Самсунг А 3, отличное состояние, б/у. Цена 32 тыс',
#   'Мобильные телефоны » Samsung',
#   'Тараз',
#   '28 ноября 2020 г.',
#   '  37 '),
#  ('Продаю Самсунг А10s',
#   '45 000 ₸',
#   'Продаю Самсунг А 10 s, отличное состояние 4 месяц, чехол книжка, с документами. Цена 45. 000 тыс',
#   'Мобильные телефоны » Samsung',
#   'Тараз',
#   '28 ноября 2020 г.',
#   '  21 '),
#  ('iPhone 11 128gb 2sim',
#   '290 000 ₸',
#   'В идеальном состояний\nАккумулятор 100%\nНикаких царапин\n1 год гарантий\nЧехол и защ.стекло в подарок\nНаушники зарядки... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  23 '),
#  ('iPhone 11 128gb 2sim',
#   '290 000 ₸',
#   'В идеальном состояний\nАккумулятор 100%\nНикаких царапин\n1 год гарантий\nЧехол и защ.стекло в подарок\nНаушники зарядки... ',
#   'Мобильные телефоны » Apple',
#   'Алматы',
#   '28 ноября 2020 г.',
#   '  23 '),
#  ...]

# %%
df = pd.DataFrame(total, columns=['names','prices', 'description', 'phone_model', 'city', 'date', 'view'])

# %%
df
# Out:
#                                                   names           prices  \
# 0                                               Телефон  Договорная цена
# 1                        Продам iPhone 11 Pro Max 64 gb        365 000 ₸
# 2                           IPhone 24Kt Gold Kazakhstan        180 000 ₸
# 3                                        iPhone 6 32 GB         35 000 ₸
# 4                                            Samsung J2         35 000 ₸
# ...                                                 ...              ...
# 1015                    Срочно продам Samsung Galaxy j5         30 000 ₸
# 1016                                      Продам кирпич          7 000 ₸
# 1017                                     Продам телефон         40 000 ₸
# 1018  Продам Samsung A71 трещена на экране на работу...         85 000 ₸
# 1019                         Huawei p30 lite  продаётся         75 000 ₸
#
#                                             description  \
# 0     Память 32гб \nСостояние среднее \nОтпечаток ра...
# 1     Продам IPhone 11 Pro Max 64 gb \n\nТелефон в и...
# 2     Продам эксклюзивный iPhone 7/128GB.\nСостояние...
# 3     Все в хорошем состоянии все работает с коробко...
# 4     Срочно продам смартфон J2 в идеальном состояни...
# ...                                                 ...
# 1015  Сегодня срочно продам Samsung Galaxy j5 в отли...
# 1016  Nokia 3310, телефон не работает! Продаю просто...
# 1017  Телефон в состояние 9 из 10. Документы в поряд...
# 1018  Samsung a71 трещина экраны на работу никак не ...
# 1019  Huawei p30 lite сатылады жагдайы жахс коп уста...
#
#                        phone_model                 city               date  \
# 0       Мобильные телефоны » Apple               Алматы  29 ноября 2020 г.
# 1       Мобильные телефоны » Apple               Алматы  29 ноября 2020 г.
# 2       Мобильные телефоны » Apple               Алматы  29 ноября 2020 г.
# 3       Мобильные телефоны » Apple  Нур-Султан (Астана)  28 ноября 2020 г.
# 4     Мобильные телефоны » Samsung             Павлодар  28 ноября 2020 г.
# ...                            ...                  ...                ...
# 1015  Мобильные телефоны » Samsung  Нур-Султан (Астана)  28 ноября 2020 г.
# 1016    Мобильные телефоны » Nokia  Нур-Султан (Астана)  28 ноября 2020 г.
# 1017    Мобильные телефоны » Meizu               Алматы  28 ноября 2020 г.
# 1018  Мобильные телефоны » Samsung               Алматы  28 ноября 2020 г.
# 1019   Мобильные телефоны » Другой                Актау  28 ноября 2020 г.
#
#          view
# 0         15
# 1         89
# 2        817
# 3        140
# 4        124
# ...       ...
# 1015     326
# 1016    5128
# 1017    4357
# 1018      26
# 1019      29
#
# [1020 rows x 7 columns]

# %%
# write the saved data as csv file
df.to_csv('project_chiron.csv', index=False)

# %%
# write the saved data as excel file
df.to_excel('project_chiron.xlsx', index=False)

# %%
driver.close()
